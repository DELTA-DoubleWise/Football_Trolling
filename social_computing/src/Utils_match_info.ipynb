# %%
import pandas as pd
import numpy as np

# %%
df_a = pd.read_csv('../data/spi_matches.csv')
df_a
# Out:
#        season        date  league_id                    league  \
# 0        2016  2016-07-09       7921   FA Women's Super League
# 1        2016  2016-07-10       7921   FA Women's Super League
# 2        2016  2016-07-10       7921   FA Women's Super League
# 3        2016  2016-07-16       7921   FA Women's Super League
# 4        2016  2016-07-17       7921   FA Women's Super League
# ...       ...         ...        ...                       ...
# 54251    2021  2022-05-29       1871  Spanish Segunda Division
# 54252    2021  2022-05-29       1871  Spanish Segunda Division
# 54253    2021  2022-05-29       1871  Spanish Segunda Division
# 54254    2021  2022-05-29       1871  Spanish Segunda Division
# 54255    2021  2022-05-29       1871  Spanish Segunda Division
#
#                   team1                team2   spi1   spi2   prob1   prob2  \
# 0       Liverpool Women              Reading  51.56  50.42  0.4389  0.2767
# ...

# %%
df_a.dtypes
# Out:
# season           int64
# date            object
# league_id        int64
# league          object
# team1           object
# team2           object
# spi1           float64
# spi2           float64
# prob1          float64
# prob2          float64
# probtie        float64
# proj_score1    float64
# proj_score2    float64
# importance1    float64
# importance2    float64
# score1         float64
# score2         float64
# xg1            float64
# xg2            float64
# nsxg1          float64
# nsxg2          float64
# adj_score1     float64
# adj_score2     float64
# dtype: object

# %%
df = df_a[df_a['league'].str.contains('Barclays')]

# %%
df.shape
# Out:
# (2280, 23)

# %%
df = df[df['season']==2020]

# %%
df
# Out:
#        season        date  league_id                   league  \
# 34045    2020  2020-09-12       2411  Barclays Premier League
# 34078    2020  2020-09-12       2411  Barclays Premier League
# 34101    2020  2020-09-12       2411  Barclays Premier League
# 34118    2020  2020-09-12       2411  Barclays Premier League
# 34174    2020  2020-09-13       2411  Barclays Premier League
# ...       ...         ...        ...                      ...
# 43453    2020  2021-05-23       2411  Barclays Premier League
# 43454    2020  2021-05-23       2411  Barclays Premier League
# 43455    2020  2021-05-23       2411  Barclays Premier League
# 43456    2020  2021-05-23       2411  Barclays Premier League
# 43457    2020  2021-05-23       2411  Barclays Premier League
#
#                       team1                 team2   spi1   spi2   prob1  \
# 34045                Fulham               Arsenal  64.18  77.16  0.2817
# 34078        Crystal Palace           Southampton  67.69  72.48  0.3698
# ...

# %%
df
# Out:
#        season        date  league_id                   league  \
# 34045    2020  2020-09-12       2411  Barclays Premier League
# 34078    2020  2020-09-12       2411  Barclays Premier League
# 34101    2020  2020-09-12       2411  Barclays Premier League
# 34118    2020  2020-09-12       2411  Barclays Premier League
# 34174    2020  2020-09-13       2411  Barclays Premier League
# ...       ...         ...        ...                      ...
# 43453    2020  2021-05-23       2411  Barclays Premier League
# 43454    2020  2021-05-23       2411  Barclays Premier League
# 43455    2020  2021-05-23       2411  Barclays Premier League
# 43456    2020  2021-05-23       2411  Barclays Premier League
# 43457    2020  2021-05-23       2411  Barclays Premier League
#
#                       team1                 team2   spi1   spi2   prob1  \
# 34045                Fulham               Arsenal  64.18  77.16  0.2817
# 34078        Crystal Palace           Southampton  67.69  72.48  0.3698
# ...

# %%
df.to_csv('../data/premier/premier_match_2020.csv',index = False)

# %%
df.columns
# Out:
# Index(['season', 'date', 'league_id', 'league', 'team1', 'team2', 'spi1',
#        'spi2', 'prob1', 'prob2', 'probtie', 'proj_score1', 'proj_score2',
#        'importance1', 'importance2', 'score1', 'score2', 'xg1', 'xg2', 'nsxg1',
#        'nsxg2', 'adj_score1', 'adj_score2'],
#       dtype='object')

# %%
df[df['importance1'].isnull()]
# Out:
#        season        date  league_id                   league  \
# 36917    2020  2020-11-28       2411  Barclays Premier League
# 37594    2020  2020-12-12       2411  Barclays Premier League
# 37816    2020  2020-12-17       2411  Barclays Premier League
#
#                    team1            team2   spi1   spi2   prob1   prob2  ...  \
# 36917    Manchester City          Burnley  93.52  66.74  0.8416  0.0382  ...
# 37594  Manchester United  Manchester City  84.18  93.95  0.2507  0.5214  ...
# 37816        Aston Villa          Burnley  74.61  65.91  0.5447  0.2089  ...
#
#        importance1  importance2  score1  score2   xg1   xg2  nsxg1  nsxg2  \
# 36917          NaN          NaN     5.0     0.0  2.23  0.40   2.17   0.74
# 37594          NaN          NaN     0.0     0.0  0.63  1.84   0.76   1.12
# 37816          NaN          NaN     0.0     0.0  1.90  0.29   1.86   0.59
#
#        adj_score1  adj_score2
# 36917        5.25         0.0
# 37594        0.00         0.0
# ...
