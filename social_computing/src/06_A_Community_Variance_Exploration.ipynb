# %%
import pandas as pd
import numpy as np
from datetime import datetime,timedelta
import matplotlib.pyplot as plt

# %%
nt_p1 = pd.read_csv('../data/comments/player/Kane_national_team.csv')

nt_p1["timestamp"] = pd.to_datetime(nt_p1["time"])

plt.figure(figsize = (12,9))
n, bins, patches = plt.hist(x=nt_p1['timestamp'], bins=30, color='#0504aa',
                            alpha=0.7, rwidth=0.85)
plt.grid(axis='y', alpha=0.75)
plt.ylabel('Num of comments')
plt.xlabel('Date')
plt.show()

# %%
pr_p1 = pd.read_csv('../data/comments/player/Kane_Premier.csv')

pr_p1["timestamp"] = pd.to_datetime(pr_p1["time"])

plt.figure(figsize = (12,9))
n, bins, patches = plt.hist(x=pr_p1['timestamp'], bins=30, color='#0504aa',
                            alpha=0.7, rwidth=0.85)
plt.grid(axis='y', alpha=0.75)
plt.ylabel('Num of comments')
plt.xlabel('Date')
plt.show()

# %%
nt_p2 = pd.read_csv('../data/comments/player/Sterling_national_team.csv')

nt_p2["timestamp"] = pd.to_datetime(nt_p2["time"])

plt.figure(figsize = (12,9))
n, bins, patches = plt.hist(x=nt_p2['timestamp'], bins=30, color='#0504aa',
                            alpha=0.7, rwidth=0.85)
plt.grid(axis='y', alpha=0.75)
plt.ylabel('Num of comments')
plt.xlabel('Date')
plt.show()

# %%
pr_p1 = pd.read_csv('../data/comments/player/Kane_Premier.csv')
pr_p1["timestamp"] = pd.to_datetime(pr_p1["time"])

pr_p2 = pd.read_csv('../data/comments/player/Sterling_Premier.csv')
pr_p2["timestamp"] = pd.to_datetime(pr_p2["time"])

pr_p3 = pd.read_csv('../data/comments/player/Walker_Premier.csv')
pr_p3["timestamp"] = pd.to_datetime(pr_p3["time"])

pr_p4 = pd.read_csv('../data/comments/player/Stones_Premier.csv')
pr_p4["timestamp"] = pd.to_datetime(pr_p4["time"])

plt.figure(figsize = (12,9))
plt.plot()
ax = plt.gca()

#ax.hist(x=pr_p1['timestamp'], bins=30, color='r',
                            #alpha=0.7, rwidth=0.85)
ax.hist(x=pr_p2['timestamp'], bins=30, color='#0504aa',
                            alpha=0.7, rwidth=0.85)
ax.hist(x=pr_p3['timestamp'], bins=30, color='g',
                            alpha=0.7, rwidth=0.85)
ax.hist(x=pr_p4['timestamp'], bins=30, color='y',
                            alpha=0.7, rwidth=0.85)

plt.grid(axis='y', alpha=0.75)
plt.ylabel('Num of comments')
plt.xlabel('Date')
plt.show()

# %%
nt_p1 = pd.read_csv('../data/comments/player/Kane_national_team.csv')
nt_p1["timestamp"] = pd.to_datetime(nt_p1["time"])

nt_p2 = pd.read_csv('../data/comments/player/Sterling_national_team.csv')
nt_p2["timestamp"] = pd.to_datetime(nt_p2["time"])

nt_p3 = pd.read_csv('../data/comments/player/Walker_national_team.csv')
nt_p3["timestamp"] = pd.to_datetime(nt_p3["time"])

nt_p4 = pd.read_csv('../data/comments/player/Stones_national_team.csv')
nt_p4["timestamp"] = pd.to_datetime(nt_p4["time"])

plt.figure(figsize = (12,9))
plt.plot()
ax = plt.gca()

ax.hist(x=nt_p1['timestamp'], bins=30, color='r',
                            alpha=0.7, rwidth=0.85)
ax.hist(x=nt_p2['timestamp'], bins=30, color='#0504aa',
                            alpha=0.7, rwidth=0.85)
ax.hist(x=nt_p3['timestamp'], bins=30, color='g',
                            alpha=0.7, rwidth=0.85)
ax.hist(x=nt_p4['timestamp'], bins=30, color='y',
                            alpha=0.7, rwidth=0.85)

plt.grid(axis='y', alpha=0.75)
plt.ylabel('Num of comments')
plt.xlabel('Date')
plt.show()

# %%
pr_p1.author.value_counts()
# Out:
# Oranjay2        35
# Intralipid      31
# Tahapatel       29
# TeddyMMR        23
# pariffinaxe     22
#                 ..
# MikaTvB          1
# tottenhamhat     1
# StareyedInLA     1
# Jozzy212         1
# Tough_Sure       1
# Name: author, Length: 3523, dtype: int64

# %%
df_p11 = pd.read_csv('../data/comments/player/sentiment/Kane_national_team_sentiment.csv')
df_p12 = pd.read_csv('../data/comments/player/sentiment/Kane_premier_sentiment.csv')

# %%
df_p11['time'] = pd.to_datetime(df_p11["time"])
df_p11['year'] = df_p11['time'].dt.year
df_p11['month'] = df_p11['time'].dt.month
s11 = df_p11.groupby(['year','month'])['sentiment_score'].mean()
#s11 = s11.reset_index()

# %%
df_p12['time'] = pd.to_datetime(df_p12["time"])
df_p12['year'] = df_p12['time'].dt.year
df_p12['month'] = df_p12['time'].dt.month
s12 = df_p12.groupby(['year','month'])['sentiment_score'].mean()

# %%
s11.loc[(2016,2)] = 0
s11.loc[(2016,4)] = 0
s11.loc[(2016,10)] = 0
s11.loc[(2016,11)] = 0
s11.loc[(2016,12)] = 0
s11.loc[(2017,1)] = 0
s11.loc[(2017,2)] = 0
s11.loc[(2017,3)] = 0
s11.loc[(2017,4)] = 0
s11.loc[(2017,5)] = 0
s11.loc[(2017,8)] = 0
s11.loc[(2017,9)] = 0
s11.loc[(2018,1)] = 0
s11.loc[(2018,2)] = 0
s11.loc[(2018,3)] = 0
s11.loc[(2018,9)] = 0
s11.loc[(2018,12)] = 0
s11.loc[(2019,2)] = 0
s11.loc[(2019,7)] = 0
s11.loc[(2019,8)] = 0
s11.loc[(2019,9)] = 0
s11.loc[(2019,11)] = 0
s11.loc[(2020,2)] = 0
s11.loc[(2020,12)] = 0
s11 = s11.reset_index().sort_values(by=['year','month'])

s11 = s11.reset_index()

s11 = s11.drop(columns=['index'])
s11
# Out:
#     year  month  sentiment_score
# 0   2016      1         0.229650
# 1   2016      2         0.000000
# 2   2016      3         0.444780
# 3   2016      4         0.000000
# 4   2016      5         0.360864
# 5   2016      6         0.241917
# 6   2016      7         0.764533
# 7   2016      8         0.865800
# 8   2016      9        -0.030000
# 9   2016     10         0.000000
# 10  2016     11         0.000000
# 11  2016     12         0.000000
# 12  2017      1         0.000000
# 13  2017      2         0.000000
# 14  2017      3         0.000000
# 15  2017      4         0.000000
# 16  2017      5         0.000000
# 17  2017      6         0.440400
# 18  2017      7         0.456100
# 19  2017      8         0.000000
# 20  2017      9         0.000000
# 21  2017     10         0.444086
# 22  2017     11         0.682833
# 23  2017     12        -0.079000
# 24  2018      1         0.000000
# 25  2018      2         0.000000
# 26  2018      3         0.000000
# ...

# %%
s12.loc[(2016,2)] = 0
s12.loc[(2016,3)] = 0
s12.loc[(2016,4)] = 0
s12.loc[(2016,8)] = 0
s12.loc[(2016,9)] = 0
s12.loc[(2016,11)] = 0
s12.loc[(2017,9)] = 0
s12.loc[(2018,2)] = 0
s12.loc[(2018,3)] = (s12.loc[(2018,2)]+s12.loc[(2018,4)])/2
s12 = s12.reset_index().sort_values(by=['year','month'])

s12 = s12.reset_index()

s12 = s12.drop(columns=['index'])
s12
# Out:
#     year  month  sentiment_score
# 0   2016      1         0.718400
# 1   2016      2         0.000000
# 2   2016      3         0.000000
# 3   2016      4         0.000000
# 4   2016      5         0.539900
# 5   2016      6         0.718400
# 6   2016      7         0.318450
# 7   2016      8         0.000000
# 8   2016      9         0.000000
# 9   2016     10         0.000000
# 10  2016     11         0.000000
# 11  2016     12         0.859100
# 12  2017      1         0.743000
# 13  2017      2         0.250100
# 14  2017      3         0.471514
# 15  2017      4         0.493767
# 16  2017      5         0.239359
# 17  2017      6         0.648600
# 18  2017      7         0.455000
# 19  2017      8         0.375760
# 20  2017      9         0.000000
# 21  2017     10         0.694629
# 22  2017     11         0.043080
# 23  2017     12         0.724675
# 24  2018      1         0.968100
# 25  2018      2         0.000000
# 26  2018      3         0.185281
# ...

# %%
df_p13 = pd.read_csv('../data/comments/player/sentiment/Kane_soccer_sentiment.csv')
df_p13['time'] = pd.to_datetime(df_p13["time"])
df_p13['year'] = df_p13['time'].dt.year
df_p13['month'] = df_p13['time'].dt.month
s13 = df_p13.groupby(['year','month'])['sentiment_score'].mean()
# Out:
# /Users/feegee2000/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
s13.loc[(2018.0,3.0)] = 0
s13 = s13.reset_index().sort_values(by=['year','month'])

s13 = s13.reset_index()

s13 = s13.drop(columns=['index'])
s13
# Out:
#       year  month  sentiment_score
# 0   2016.0    1.0         0.304211
# 1   2016.0    2.0         0.255746
# 2   2016.0    3.0         0.251489
# 3   2016.0    4.0         0.281967
# 4   2016.0    5.0         0.226120
# 5   2016.0    6.0         0.083324
# 6   2016.0    7.0         0.226330
# 7   2016.0    8.0         0.251642
# 8   2016.0    9.0         0.177662
# 9   2016.0   10.0         0.207245
# 10  2016.0   11.0         0.189942
# 11  2016.0   12.0         0.197483
# 12  2017.0    1.0         0.226234
# 13  2017.0    2.0         0.241408
# 14  2017.0    3.0         0.269496
# 15  2017.0    4.0         0.298991
# 16  2017.0    5.0         0.268491
# 17  2017.0    6.0         0.259914
# 18  2017.0    7.0         0.290615
# 19  2017.0    8.0         0.254146
# 20  2017.0    9.0         0.235306
# 21  2017.0   10.0         0.239498
# 22  2017.0   11.0         0.248748
# 23  2017.0   12.0         0.211679
# 24  2018.0    1.0         0.219948
# 25  2018.0    2.0         0.112182
# ...

# %%
plt.figure(figsize = (12,9))
plt.plot()
ax = plt.gca()
plt.grid(axis='y', alpha=0.75)
ax.plot(s11.index,s11.sentiment_score,color='r',marker='o')
ax.plot(s12.index,s12.sentiment_score,color='#0504aa',marker='o')
ax.plot(s13.index,s13.sentiment_score,color='g',marker='o')

# %%
df_p13 = pd.read_csv('../data/comments/player/sentiment/Kane_soccer_sentiment.csv')
df_p13['time'] = pd.to_datetime(df_p13["time"])
df_p13['year'] = df_p13['time'].dt.year
df_p13['month'] = df_p13['time'].dt.month
s13 = df_p13.groupby(['year','month'])['sentiment_score'].mean()
s13.loc[(2018.0,3.0)] = (s13.loc[(2018.0,2.0)]+s13.loc[(2018.0,4.0)])/2
s13 = s13.reset_index().sort_values(by=['year','month'])

s13 = s13.reset_index()

s13 = s13.drop(columns=['index'])
s13
# Out:
# /Users/feegee2000/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       year  month  sentiment_score
# 0   2016.0    1.0         0.304211
# 1   2016.0    2.0         0.255746
# 2   2016.0    3.0         0.251489
# 3   2016.0    4.0         0.281967
# 4   2016.0    5.0         0.226120
# 5   2016.0    6.0         0.083324
# 6   2016.0    7.0         0.226330
# 7   2016.0    8.0         0.251642
# 8   2016.0    9.0         0.177662
# 9   2016.0   10.0         0.207245
# 10  2016.0   11.0         0.189942
# 11  2016.0   12.0         0.197483
# 12  2017.0    1.0         0.226234
# 13  2017.0    2.0         0.241408
# 14  2017.0    3.0         0.269496
# 15  2017.0    4.0         0.298991
# 16  2017.0    5.0         0.268491
# 17  2017.0    6.0         0.259914
# 18  2017.0    7.0         0.290615
# ...

# %%
df_p23 = pd.read_csv('../data/comments/player/sentiment/Sterling_soccer_sentiment.csv')
df_p23['time'] = pd.to_datetime(df_p23["time"])
df_p23['year'] = df_p23['time'].dt.year
df_p23['month'] = df_p23['time'].dt.month
s23 = df_p23.groupby(['year','month'])['sentiment_score'].mean()

s23.loc[(2018.0,3.0)] = (s23.loc[(2018.0,2.0)]+s23.loc[(2018.0,4.0)])/2
s23 = s23.reset_index().sort_values(by=['year','month'])

s23 = s23.reset_index()

s23 = s23.drop(columns=['index'])
s23
# Out:
# /Users/feegee2000/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       year  month  sentiment_score
# 0   2016.0    1.0         0.226267
# 1   2016.0    2.0         0.242820
# 2   2016.0    3.0         0.228599
# 3   2016.0    4.0         0.191808
# 4   2016.0    5.0         0.229996
# 5   2016.0    6.0         0.074698
# 6   2016.0    7.0         0.221102
# 7   2016.0    8.0         0.195355
# 8   2016.0    9.0         0.266826
# 9   2016.0   10.0         0.183201
# 10  2016.0   11.0         0.150925
# 11  2016.0   12.0         0.225243
# 12  2017.0    1.0         0.056782
# 13  2017.0    2.0         0.180901
# 14  2017.0    3.0         0.172010
# 15  2017.0    4.0         0.230401
# 16  2017.0    5.0         0.276302
# 17  2017.0    6.0         0.222053
# 18  2017.0    7.0         0.259469
# ...

# %%
df_p33 = pd.read_csv('../data/comments/player/sentiment/Stones_soccer_sentiment.csv')
df_p33['time'] = pd.to_datetime(df_p33["time"])
df_p33['year'] = df_p33['time'].dt.year
df_p33['month'] = df_p33['time'].dt.month
s33 = df_p33.groupby(['year','month'])['sentiment_score'].mean()

s33.loc[(2018.0,3.0)] = (s33.loc[(2018.0,2.0)]+s33.loc[(2018.0,4.0)])/2
s33 = s33.reset_index().sort_values(by=['year','month'])

s33 = s33.reset_index()

s33 = s33.drop(columns=['index'])
s33
# Out:
#       year  month  sentiment_score
# 0   2016.0    1.0         0.220371
# 1   2016.0    2.0         0.184855
# 2   2016.0    3.0         0.138430
# 3   2016.0    4.0         0.136121
# 4   2016.0    5.0         0.176299
# 5   2016.0    6.0         0.226039
# 6   2016.0    7.0         0.314832
# 7   2016.0    8.0         0.269645
# 8   2016.0    9.0         0.174197
# 9   2016.0   10.0         0.111109
# 10  2016.0   11.0         0.159395
# 11  2016.0   12.0         0.098249
# 12  2017.0    1.0         0.136466
# 13  2017.0    2.0         0.065840
# 14  2017.0    3.0         0.179379
# 15  2017.0    4.0         0.216533
# 16  2017.0    5.0         0.267965
# 17  2017.0    6.0         0.177513
# 18  2017.0    7.0         0.202716
# 19  2017.0    8.0         0.174667
# 20  2017.0    9.0        -0.445943
# 21  2017.0   10.0         0.255829
# 22  2017.0   11.0         0.234154
# 23  2017.0   12.0         0.302294
# 24  2018.0    1.0         0.196836
# 25  2018.0    2.0         0.282561
# ...

# %%
plt.figure(figsize = (12,9))
plt.plot()
ax = plt.gca()
plt.grid(axis='y', alpha=0.75)
ax.plot(s13.index,s13.sentiment_score,color='r',marker='o',label='Kane')
ax.plot(s23.index,s23.sentiment_score,color='#0504aa',marker='o',label='Sterling')
ax.plot(s33.index,s33.sentiment_score,color='g',marker='o',label='Stones')
ax.legend()

# %%
plt.figure(figsize = (12,9))
plt.plot()
ax = plt.gca()

ax.hist(x=df_p13['time'], bins=30, color='r',
                            alpha=0.7, rwidth=0.85)
ax.hist(x=df_p23['time'], bins=30, color='#0504aa',
                            alpha=0.7, rwidth=0.85)
ax.hist(x=df_p33['time'], bins=30, color='g',
                            alpha=0.7, rwidth=0.85)

plt.grid(axis='y', alpha=0.75)
plt.ylabel('Num of comments')
plt.xlabel('Date')
plt.show()

# %%
df_p13_author = df_p13.author.value_counts()

# %%
#df_p13_author = (df_p13_author.loc[df_p13_author.values>=10]).to_frame()
df_p13_author = df_p13_author.drop('[deleted]',axis=0)

# %%
df_p13_author_50 = df_p13_author.loc[df_p13_author.author>=50]
df_p13_author_50 = df_p13_author_50.reset_index()
df_p13_author_50['count'] = df_p13_author_50['author']
df_p13_author_50['author'] = df_p13_author_50['index']
df_p13_author_50.drop('index',axis=1,inplace=True)

# %%
df_p13_author_50
# Out:
#                    author  count
# 0              JavaSoCool   1036
# 1          CodifiedRadian    870
# 2             taylorrible    779
# 3              ZaDoruphin    596
# 4                 shatoyo    569
# 5       xaviernoodlebrain    506
# 6                yaniv297    494
# 7               Mick4Audi    462
# 8               john87000    429
# 9              Pele20Alli    412
# 10          icemankiller8    384
# 11            JakeNutters    356
# 12      wheresmyspacebar2    354
# 13               melihs11    344
# 14             YoungDan23    325
# 15             Spursfan14    325
# 16           CheekyKunt68    317
# 17          legingerfreak    310
# 18        thatbluemoonguy    309
# 19             Cowdude179    305
# 20               dave1992    270
# 21                 twersx    250
# 22                  naryn    249
# 23           FenrirXXVIII    243
# 24                DEUK_96    242
# 25           Vhascometo__    234
# 26             Blue_Shore    230
# ...

# %%
df_p13_author_50.to_csv('../data/author/Kane_soccer_author_50.csv',index=False)

# %%
df_p13_author.index[0]
# Out:
# 'JavaSoCool'

# %%
df_p23.author.value_counts()
# Out:
# [deleted]               612
# thatbluemoonguy         504
# domalino                406
# Pottsaayy               402
# GJXN1990                393
# Good_Kev_M-A-N_City     322
# raghavk180              217
# JavaSoCool              215
# CodifiedRadian          211
# damrider                199
# bluemoonmotherfucker    187
# Kanedauke               177
# BoosterGoldGL           177
# mrkingkoala             173
# england2022wcchamps     172
# Eyeknowthis             171
# dave1992                170
# twersx                  166
# JakeNutters             156
# Infamy444               147
# Chiswell123             145
# Cowdude179              143
# Thesolly180             142
# Lyrical_Forklift        142
# Tim-Sanchez             137
# Cardealer1000           137
# DatDominican            134
# Gwyn-LordOfPussy        133
# cirad                   128
# Mick4Audi               126
# unexpectedvillain       123
# RektSquared             123
# DEUK_96                 122
# ...

# %%
df_p33.author.value_counts()
# Out:
# Pottsaayy               285
# [deleted]               271
# thatbluemoonguy         228
# GJXN1990                216
# Good_Kev_M-A-N_City     191
# domalino                185
# Mozezz                  137
# lmh971                  126
# Tautou--                117
# RektSquared             113
# LessBrain               104
# damrider                 99
# england2022wcchamps      90
# raghavk180               89
# OnceUponAStarryNight     79
# twersx                   77
# dave1992                 77
# BoosterGoldGL            76
# Gwyn-LordOfPussy         75
# Masterofknees            73
# rickhelgason             73
# Eyeknowthis              70
# bustedracquet            70
# sam3123                  70
# TomShoe                  69
# NotClayMerritt           62
# JavaSoCool               61
# GoldenIron               60
# 3V3RT0N                  60
# practically_floored      55
# bluemoonmotherfucker     55
# kokin33                  55
# Infamy444                54
# ...

# %%
df_co = pd.read_csv('../data/comments/player/author/Kane_soccer_author_comments.csv')
df_co.shape
# Out:
# (1790502, 5)

# %%
df_co['time'] = pd.to_datetime(df_co['time'])
df_co['year'] = df_co['time'].dt.year
df_co['month'] = df_co['time'].dt.month

# %%
pd.set_option('display.max_rows', 100)
df_co.groupby(['subreddit'])['id'].count().sort_values(ascending=False)[:100]
# Out:
# subreddit
# soccer                   1097435
# coys                      122593
# nfl                        52209
# chelseafc                  35843
# ukpolitics                 28284
# reddevils                  27400
# nba                        20704
# formula1                   20449
# FIFA                       18030
# Cricket                    13543
# NYYankees                  12699
# Gunners                    11690
# FantasyPL                  11537
# SquaredCircle              10653
# LiverpoolFC                 8411
# unitedkingdom               7952
# worldnews                   7239
# movies                      7107
# hiphopheads                 6808
# baseball                    5968
# AskReddit                   5778
# politics                    4845
# NYGiants                    4708
# gratefuldead                4689
# peloton                     3990
# realmadrid                  3914
# MMA                         3843
# MCFC                        3802
# ...

# %%
df_p14 = pd.read_csv('../data/comments/player/sentiment/Kane_TOT_sentiment.csv')
df_p14['time'] = pd.to_datetime(df_p14["time"])
df_p14['year'] = df_p14['time'].dt.year
df_p14['month'] = df_p14['time'].dt.month
s14 = df_p14.groupby(['year','month'])['sentiment_score'].mean()

# %%
s14.loc[(2018.0,3.0)] = (s14.loc[(2018.0,2.0)]+s14.loc[(2018.0,4.0)])/2
s14 = s14.reset_index().sort_values(by=['year','month'])

s14 = s14.reset_index()

s14 = s14.drop(columns=['index'])
s14
# Out:
#     year  month  sentiment_score
# 0   2016      1         0.304561
# 1   2016      2         0.220254
# 2   2016      3         0.206918
# 3   2016      4         0.279430
# 4   2016      5         0.275267
# 5   2016      6         0.230285
# 6   2016      7         0.381171
# 7   2016      8         0.298909
# 8   2016      9         0.242722
# 9   2016     10         0.213065
# 10  2016     11         0.232070
# 11  2016     12         0.196488
# 12  2017      1         0.276565
# 13  2017      2         0.205653
# 14  2017      3         0.263822
# 15  2017      4         0.303258
# 16  2017      5         0.278986
# 17  2017      6         0.346098
# 18  2017      7         0.357290
# 19  2017      8         0.227062
# 20  2017      9         0.387091
# 21  2017     10         0.259192
# 22  2017     11         0.224973
# 23  2017     12         0.245026
# 24  2018      1         0.251133
# 25  2018      2         0.130337
# 26  2018      3         0.159452
# ...

# %%
plt.figure(figsize = (12,9))
plt.plot()
ax = plt.gca()
plt.grid(axis='y', alpha=0.75)
ax.plot(s12.index[48:],s12.sentiment_score[48:],color='g',marker='o',label='Kane_Premier')
ax.plot(s13.index[48:],s13.sentiment_score[48:],color='r',marker='o',label='Kane_soccer')
ax.plot(s14.index[48:],s14.sentiment_score[48:],color='b',marker='o',label='Kane_TOT')
ax.legend()

# %%
plt.figure(figsize = (12,9))
plt.plot()
ax = plt.gca()

#ax.hist(x=df_p13['time'], bins=30, color='r',
                            #alpha=0.7, rwidth=0.85,label='soccer')
#ax.hist(x=df_p14['time'], bins=30, color='b',
                            #alpha=0.7, rwidth=0.85,label='TOT')
ax.hist(x=df_p12['time'], bins=30, color='g',
                            alpha=0.7, rwidth=0.85,label='Premier')

plt.grid(axis='y', alpha=0.75)
plt.ylabel('Num of comments')
plt.xlabel('Date')
plt.show()

# %%
df_eu = pd.read_csv('../data/comments/player/author/euro_Kane_soccer_author_comments.csv')
df_eu.shape
# Out:
# (1044076, 5)

# %%
df_eu['time'] = pd.to_datetime(df_eu['time'])
df_eu['year'] = df_eu['time'].dt.year
df_eu['month'] = df_eu['time'].dt.month

# %%
pd.set_option('display.max_rows', 100)
df_eu.groupby(['subreddit','author'])['id'].count().sort_values(ascending=False)[:100]
# Out:
# subreddit      author
# soccer         Cowdude179              23022
#                Ciao9                   19378
#                thatbluemoonguy         17644
#                TheUltimateCF           15630
#                AnnieIWillKnow          15535
#                twersx                  12821
#                icemankiller8           11773
#                HakunaMatata69          11741
#                not1yo2avg3person       11234
#                ahmad3093               11086
#                sul01                   10781
#                abrasiveauror           10061
#                SomeIrishFiend          10028
#                shatoyo                  9975
#                jim0wheel1               9792
#                ugotbaited               9139
#                3V3RT0N                  9082
#                Kanedauke                9049
#                MyNameIsUrl1626          8975
# Cricket        _rickjames               8889
# ...
